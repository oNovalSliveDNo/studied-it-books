# %%
from IPython.display import Image, display


filepath = 'data/pictures/'

# %% [markdown]
# # Что такое машинное и глубокое обучение

# %%
display(Image(filename=filepath+'what_is_machine_learning.png', 
              width=500, 
              # height=300
             ))

# %% [markdown]
# # Данные = Опыт

# %%
display(Image(filename=filepath+'human_vs_pc.png', 
              width=700, 
              # height=500
             ))

# %% [markdown]
# # Вспомнить - сформулировать - спрогнозировать

# %%
display(Image(filename=filepath+'make_a_decision.png', 
              width=700, 
              # height=500
             ))

# %%
display(Image(filename=filepath+'model1.png', 
              width=1000, 
              # height=500
             ))

# %%
display(Image(filename=filepath+'model2.png', 
              width=1000, 
              # height=500
             ))

# %%
display(Image(filename=filepath+'model3.png', 
              width=1000, 
              # height=500
             ))

# %%
display(Image(filename=filepath+'model4.png', 
              width=1000, 
              # height=500
             ))

# %%
display(Image(filename=filepath+'model5.png', 
              width=1000, 
              # height=500
             ))

# %%
display(Image(filename=filepath+'model6.png', 
              width=1000, 
              # height=500
             ))
