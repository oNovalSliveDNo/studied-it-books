# %%
from IPython.display import Image, display


filepath = 'data/pictures/'

# %% [markdown]
# # Типы машинного обучения

# %%
display(Image(filename=filepath+'types_of_machine_learning.png', 
              width=1000, 
              # height=300
             ))
